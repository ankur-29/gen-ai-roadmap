# %%
import pandas as pd
import numpy as np

# plotting graphs using pandas
# for ploting graph we req, plot() --> df.plot()

df = pd.read_csv('youtube_2025_dataset.csv')

avg = df["Avg Video Length (min)"].mean()

avg
# Out:
# np.float64(24.00454)

# %%
avg = df["Avg Video Length (min)"]

import matplotlib
print(matplotlib.__version__)

avg.plot()
# Out:
# 3.11.0
# Matplotlib is building the font cache; this may take a moment.
# <Axes: >

# %%
print(df.columns)
df.sort_values(by="Total Videos",ascending=False).head(15).plot(
    x="Youtuber Name",
    y="Total Videos",
    kind="bar"
)
# Out:
# Index(['Channel Name', 'Youtuber Name', 'Total Videos', 'Best Video',
#        'Avg Video Length (min)', 'Total Subscribers', 'Members Count',
#        'AI Generated Content (%)', 'Neural Interface Compatible',
#        'Metaverse Integration Level', 'Quantum Computing Topics',
#        'Holographic Content Rating', 'Engagement Score',
#        'Content Value Index'],
#       dtype='str')
# <Axes: xlabel='Youtuber Name'>

# %%
df.sort_values(by="Total Videos",ascending=False).head(15).plot(
    x="Youtuber Name",
    y="Total Videos",
    kind="pie"
)
# Out:
# <Axes: >
