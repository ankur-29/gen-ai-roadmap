# %% [markdown]
# # Streamlit

# %% [markdown]
# ## Streamlit is an open source Python lib used to built interactive application for data science and machine learning with minimal effort.

# %% [markdown]
# ## Why to use Streamlit
#
# #### Easy to use
# #### Fast development
# #### Interactive UI Elements ---> Buttons, Sliders etc
# #### Great for data science ---> Support Pandas, Numpy, Matplotlib etc
